# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv(r"C:\Users\ss\Desktop\train.csv",encoding="latin1")

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1493           1183     1          0.5         1   3       1          48
# 1494            574     1          2.0         1   0       1          26
# 1495           1472     0          3.0         0   4       1          20
# 1496           1868     1          0.5         0   2       1          40
# 1497           1375     0          2.9         0   2       0          20
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
train.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
test=pd.read_csv(r"C:\Users\ss\Desktop\test.csv",encoding="latin1")

# %%
test
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              881     0          1.0         0   1       0          64
# 1             1742     1          0.5         1   5       1          43
# 2             1225     0          0.7         1   6       0          60
# 3             1970     1          0.5         1   0       1          15
# 4             1186     1          0.5         1   2       0          21
# ..             ...   ...          ...       ...  ..     ...         ...
# 497            794     1          0.5         1   0       1           2
# 498           1965     1          2.6         1   0       0          39
# 499           1911     0          0.9         1   1       1          36
# 500           1512     0          0.9         0   4       1          46
# 501            510     1          2.0         1   5       1          45
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
test.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
xtrain=train.iloc[:,:-1]
ytrain=train.iloc[:,-1]
xtest=test.iloc[:,:-1]
ytest=test.iloc[:,-1]

# %%
scale=StandardScaler()
x_train=scale.fit_transform(xtrain)
x_test=scale.transform(xtest)

# %%
Lr=LogisticRegression(random_state=42,n_jobs=-1)

# %%
Lr.fit(x_train,ytrain)
# Out:
# LogisticRegression(n_jobs=-1, random_state=42)

# %%
Lr.predict(x_test)
# Out:
# array([1, 1, 2, 2, 1, 1, 3, 0, 1, 2, 2, 2, 1, 1, 3, 0, 1, 0, 2, 3, 3, 2,
#        3, 1, 1, 0, 0, 3, 2, 3, 1, 1, 0, 3, 3, 0, 2, 2, 1, 2, 2, 0, 2, 3,
#        3, 3, 2, 2, 3, 2, 2, 1, 1, 1, 2, 0, 1, 0, 3, 2, 1, 2, 2, 2, 2, 1,
#        0, 0, 0, 1, 2, 1, 0, 3, 2, 0, 3, 2, 0, 1, 2, 1, 0, 0, 0, 2, 0, 3,
#        0, 1, 2, 3, 3, 2, 1, 2, 1, 2, 3, 0, 2, 3, 1, 0, 3, 1, 0, 2, 1, 2,
#        1, 2, 3, 2, 3, 2, 3, 3, 3, 3, 1, 2, 2, 3, 1, 1, 1, 0, 0, 3, 2, 1,
#        0, 3, 3, 1, 0, 3, 2, 1, 2, 3, 2, 2, 3, 1, 1, 1, 1, 0, 2, 1, 0, 1,
#        0, 3, 0, 3, 1, 1, 3, 3, 1, 1, 1, 3, 2, 1, 3, 1, 1, 1, 3, 0, 1, 1,
#        3, 2, 1, 2, 2, 3, 2, 1, 1, 1, 3, 3, 3, 0, 3, 2, 3, 1, 3, 2, 1, 2,
#        3, 3, 0, 0, 0, 2, 2, 0, 2, 0, 1, 1, 3, 3, 0, 1, 2, 0, 2, 0, 2, 2,
#        2, 0, 2, 0, 2, 0, 2, 1, 2, 3, 1, 3, 0, 0, 2, 2, 3, 3, 1, 2, 1, 1,
#        3, 0, 0, 2, 1, 0, 1, 2, 1, 3, 0, 1, 3, 0, 3, 3, 3, 2, 0, 3, 1, 1,
#        0, 2, 2, 2, 0, 3, 3, 0, 3, 2, 3, 0, 2, 0, 2, 1, 3, 3, 0, 3, 2, 0,
# ...

# %%
ypred=Lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.9601593625498008

# %%
accuracy_score(ytrain,Lr.predict(x_train))
# Out:
# 0.9786381842456608

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[123,   2,   0,   0],
#        [  4, 123,   2,   0],
#        [  0,   6, 118,   3],
#        [  0,   0,   3, 118]], dtype=int64)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       125
#            1       0.94      0.95      0.95       129
#            2       0.96      0.93      0.94       127
#            3       0.98      0.98      0.98       121
#
#     accuracy                           0.96       502
#    macro avg       0.96      0.96      0.96       502
# weighted avg       0.96      0.96      0.96       502

# %%
ypred.tolist()
# Out:
# [1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  3,
#  0,
#  1,
#  2,
#  2,
#  2,
#  1,
#  1,
#  3,
#  0,
#  1,
#  0,
#  2,
#  3,
#  3,
#  2,
#  3,
#  1,
#  1,
#  0,
#  0,
#  3,
#  2,
#  3,
#  1,
#  1,
#  0,
#  3,
#  3,
#  0,
#  2,
#  2,
#  1,
#  2,
#  2,
#  0,
#  2,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  0,
#  1,
#  0,
#  3,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  0,
#  0,
#  0,
#  1,
#  2,
#  1,
#  0,
#  3,
#  2,
#  0,
#  3,
#  2,
#  0,
#  1,
#  2,
#  1,
#  0,
#  0,
#  0,
#  2,
#  0,
#  3,
#  0,
#  1,
#  2,
#  3,
#  3,
#  2,
#  1,
#  2,
#  1,
#  2,
#  3,
#  0,
#  2,
#  3,
#  1,
#  0,
#  3,
#  1,
#  0,
#  2,
#  1,
#  2,
#  1,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  1,
#  2,
#  2,
#  3,
#  1,
#  1,
#  1,
#  0,
#  0,
#  3,
#  2,
#  1,
#  0,
#  3,
#  3,
#  1,
#  0,
#  3,
#  2,
#  1,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  1,
#  1,
#  1,
#  0,
#  2,
#  1,
#  0,
#  1,
#  0,
#  3,
#  0,
#  3,
#  1,
#  1,
#  3,
#  3,
#  1,
#  1,
#  1,
#  3,
# ...

# %%
data={"Prediction":ypred}

# %%
df=pd.DataFrame(data)

# %%
df.to_csv("Output.csv",index=False)

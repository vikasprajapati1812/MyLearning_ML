# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.relplot(
    *,
    x=None,
    y=None,
    hue=None,
    size=None,
    style=None,
    data=None,
    row=None,
    col=None,
    col_wrap=None,
    row_order=None,
    col_order=None,
    palette=None,
    hue_order=None,
    hue_norm=None,
    sizes=None,
    size_order=None,
    size_norm=None,
    markers=None,
    dashes=None,
    style_order=None,
    legend='auto',
    kind='scatter',
    height=5,
    aspect=1,
    facet_kws=None,
    units=None,
    **kwargs,)
# Out:
#   Input In [4]
#     *,
#      ^
# SyntaxError: invalid syntax

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme(style="darkgrid")
sns.relplot(data=tips,x="total_bill",y="tip")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",style="smoker")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",style="smoker",hue="smoker")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",style="time",hue="smoker")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",style="smoker",hue="size")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",palette="ch:r=-.5,1=.75",hue="size")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 sns.relplot(data=tips,x="total_bill",y="tip",palette="ch:r=-.5,1=.75",hue="size")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.relplot(data=tips,x="total_bill",y="tip",palette="ch:r=-.5,1=.75",hue="size")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 sns.relplot(data=tips,x="total_bill",y="tip",palette="ch:r=-.5,1=.75",hue="size")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.relplot(data=tips,x="total_bill",y="tip",size="size")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",size="size",sizes=(15,200))

# %%
sns.relplot(data=tips,x="total_bill",y="tip",size="size",sizes=(50,200))

# %%
sns.relplot(data=tips,x="total_bill",y="tip",size="size",sizes=(50,400))

# %%
sns.relplot(data=tips,x="total_bill",y="tip",size="size",kind="line")

# %%
dowjones=sns.load_dataset("dowjones")
print(dowjones)
sns.relplot(data=dowjones,x="Date",y="Price",kind="line")
# Out:
#            Date   Price
# 0    1914-12-01   55.00
# 1    1915-01-01   56.55
# 2    1915-02-01   56.00
# 3    1915-03-01   58.30
# 4    1915-04-01   66.45
# ..          ...     ...
# 644  1968-08-01  883.72
# 645  1968-09-01  922.80
# 646  1968-10-01  955.47
# 647  1968-11-01  964.12
# 648  1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
fmri=sns.load_dataset("fmri")
print(fmri)
sns.relplot(data=fmri,x="timepoint",y="signal",kind="line")
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal")

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal",estimator=None)

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal",hue="event")

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal",hue="region",style="event")

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal",hue="region",style="event",dashes=False,markers=True)

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal",hue="region",style="event",dashes=False)

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal",hue="region",style="event",markers=True)

# %%
sns.relplot(data=fmri,kind="scatter",x="timepoint",y="signal",hue="region",style="event",markers=True)

# %%
sns.relplot(data=fmri,kind="scatter",x="timepoint",y="signal",hue="region",style="event")

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal",hue="region",style="event",markers=True)

# %%
dots=sns.load_dataset("dots").query("align=='dots'")
sns.relplot(data=dots,kind="line",x="time",y="firing_rate",hue="coherence",style="choice")

# %%
dots=sns.load_dataset("dots").query("align=='dots'")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057
#
# [394 rows x 5 columns]

# %%
dots=sns.load_dataset("dots")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.relplot(data=dots,kind="line",x="time",y="firing_rate",hue="coherence",style="choice")

# %%
dots=sns.load_dataset("dots").query("align=='dots'")
print(dots)
palette=sns.cubehelix_palette(light=.8,n_colors=6)
sns.relplot(data=dots,kind="line",x="time",y="firing_rate",hue="coherence",style="choice",palette=palette)
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057
#
# [394 rows x 5 columns]

# %%
sns.relplot(data=fmri,kind="line",x="timepoint",y="signal",hue="subject",col="region",row="event",height=3,estimator=None)

# %%
#########################     Visualizing distributions of data

# %%
#Plotting univariate histograms

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=3)

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=5)

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=10)

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=8)

# %%
sns.histplot(penguins,x="flipper_length_mm",bins=15)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(penguins,x="flipper_length_mm",bins=8)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(penguins,x="flipper_length_mm",y="body_mass_g",bins=15)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.displot(penguins,x="flipper_length_mm",y="body_mass_g",bins=15)

# %%
sns.displot(penguins, x="flipper_length_mm", bins=20)

# %%
tips = sns.load_dataset("tips")
sns.displot(tips, x="size")

# %%
sns.histplot(tips,x="size")
# Out:
# <AxesSubplot:xlabel='size', ylabel='Count'>

# %%
sns.displot(tips, x="size", bins=[1, 2, 3, 4, 5, 6, 7])

# %%
sns.displot(tips, x="size", bins=[1, 2, 3, 4, 5, 6, 7,9,12,20])

# %%
sns.displot(tips, x="size", discrete=True) #This can also be accomplished by setting discrete=True, which chooses bin breaks that represent the unique values in a dataset with bars that are centered on their corresponding value.

# %%
sns.displot(tips, x="day", shrink=.8)#It’s also possible to visualize the distribution of a categorical variable using the logic of a histogram. Discrete bins are automatically set for categorical variables, but it may also be helpful to “shrink” the bars slightly to emphasize the categorical nature of the axis:

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species")

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species",multiple = "dodge")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species",multiple = "stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species",multiple = "fill")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", element="step")

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="poly")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="sex", multiple="dodge")

# %%
sns.displot(penguins, x="flipper_length_mm", col="sex")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(penguins, x="flipper_length_mm", col="island")

# %%
sns.displot(penguins, x="flipper_length_mm", col="species")

# %%
sns.displot(penguins, x="flipper_length_mm", row="species")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="density")

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", stat="probability")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Probability'>

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", stat="percent")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Percent'>

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", stat="frequency")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Frequency'>

# %% [markdown]
# # Normalized histogram statistics

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="density", common_norm=False)

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="probability")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="probability")

# %% [markdown]
# # Kernel density estimation

# %%
sns.displot(penguins, x="flipper_length_mm", kind="kde")

# %%
#Choosing the smoothing bandwidth
sns.displot(penguins, x="flipper_length_mm", kind="kde", bw_adjust=.25)

# %%
#Note how the narrow bandwidth makes the bimodality much more apparent, but the curve is much less smooth. In contrast, a larger bandwidth obscures the bimodality almost completely:

sns.displot(penguins, x="flipper_length_mm", kind="kde", bw_adjust=2)

# %%
#Conditioning on other variables
#As with histograms, if you assign a hue variable, a separate density estimate will be computed for each level of that variable:

sns.displot(penguins, x="flipper_length_mm", hue="species", kind="kde")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", kind="kde", multiple="stack")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", kind="kde", fill=True)

# %% [markdown]
# # Kernel density estimation pitfalls

# %%
sns.displot(tips, x="total_bill", kind="kde")

# %%
sns.displot(tips, x="total_bill", kind="kde", cut=0)

# %%
diamonds = sns.load_dataset("diamonds")
sns.displot(diamonds, x="carat", kind="kde")

# %%
sns.displot(diamonds, x="carat")

# %%
sns.displot(diamonds, x="carat", kde=True)

# %% [markdown]
# # Empirical cumulative distributions
# A third option for visualizing distributions computes the “empirical cumulative distribution function” (ECDF). This plot draws a monotonically-increasing curve through each datapoint such that the height of the curve reflects the proportion of observations with a smaller value:

# %%
sns.displot(penguins, x="flipper_length_mm", kind="ecdf")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", kind="ecdf")

# %% [markdown]
# # Visualizing bivariate distributions

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", binwidth=(2, .5))

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", binwidth=(2, .5), cbar=True)

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde", thresh=.2, levels=4)

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde", levels=[.01, .05, .1, .8])

# %%
sns.displot(diamonds, x="price", y="clarity", log_scale=(True, False))

# %%
sns.displot(diamonds, x="color", y="clarity")

# %% [markdown]
# # Distribution visualization in other settings

# %% [markdown]
# ### Plotting joint and marginal distributions

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.jointplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="species",
    kind="kde"
)

# %%
g = sns.JointGrid(data=penguins, x="bill_length_mm", y="bill_depth_mm")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)

# %%
sns.displot(
    penguins, x="bill_length_mm", y="bill_depth_mm",
    kind="kde", rug=True
)

# %%
sns.relplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
sns.rugplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.pairplot(penguins)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.relplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try scatterplot
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try scatterplot
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try scatterplot
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try scatterplot
#   warnings.warn(msg, UserWarning)
# ...

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.boxplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.boxenplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.boxenplot)
g.map_diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)
g.map_upper(sns.boxenplot)
g.map_lower(sns.kdeplot, fill=True)

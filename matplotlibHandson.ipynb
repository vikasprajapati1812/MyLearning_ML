#   7.42474916  7.45819398  7.4916388   7.52508361  7.55852843  7.59197324
#   7.62541806  7.65886288  7.69230769  7.72575251  7.75919732  7.79264214
#   7.82608696  7.85953177  7.89297659  7.9264214   7.95986622  7.99331104
#   8.02675585  8.06020067  8.09364548  8.1270903   8.16053512  8.19397993
#   8.22742475  8.26086957  8.29431438  8.3277592   8.36120401  8.39464883
#   8.42809365  8.46153846  8.49498328  8.52842809  8.56187291  8.59531773
#   8.62876254  8.66220736  8.69565217  8.72909699  8.76254181  8.79598662
#   8.82943144  8.86287625  8.89632107  8.92976589  8.9632107   8.99665552
#   9.03010033  9.06354515  9.09698997  9.13043478  9.1638796   9.19732441
#   9.23076923  9.26421405  9.29765886  9.33110368  9.36454849  9.39799331
#   9.43143813  9.46488294  9.49832776  9.53177258  9.56521739  9.59866221
#   9.63210702  9.66555184  9.69899666  9.73244147  9.76588629  9.7993311
#   9.83277592  9.86622074  9.89966555  9.93311037  9.96655518 10.        ]

# %%
10/300
# Out:
# 0.03333333333333333

# %%
# Out:
# 0.03666666666666667

# %%
ax.plot(x,y)

# %%
fig,ax=plt.subplots()
x=np.linspace(0,10,300)
y=np.sin(x)+x
plt.plot(x,y)

# %%
fig,ax=plt.subplots()
x=np.linspace(0,10,300)
y=np.sin(x)+x
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,"r--")

# %%
plt.plot(x,y,"r--")
plt.xticks(textstyle=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 plt.plot(x,y,"r--")
# ----> 2 plt.xticks(textstyle=20)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:1793, in xticks(ticks, labels, **kwargs)
#    1791     labels = ax.get_xticklabels()
#    1792     for l in labels:
# -> 1793         l.update(kwargs)
#    1794 else:
#    1795     labels = ax.set_xticklabels(labels, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\text.py:172, in Text.update(self, kwargs)
#     170 # Update bbox last, as it depends on font properties.
#     171 bbox = kwargs.pop("bbox", sentinel)
# --> 172 super().update(kwargs)
#     173 if bbox is not sentinel:
#     174     self.set_bbox(bbox)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Text' object has no property 'textstyle'

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
fig.suptitle("Our  first plot",fontsize=20)
ax1,ax2,ax3=axes
x=np.linspace(0,10,500)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
fig.suptitle("Our  first plot",fontsize=20)
ax1,ax2,ax3=axes
x=np.linspace(0,10,500)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

ax1.set_ylabel("sin(x)",fontsize=30)
ax2.set_ylabel("cos(x)",fontsize=30)
ax3.set_ylabel("tan(x)",fontsize=30)
# Out:
# Text(0, 0.5, 'tan(x)')

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
fig.suptitle("Our  first plot",fontsize=20)
ax1,ax2,ax3=axes
x=np.linspace(0,10,500)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

ax1.set_ylabel("sin(x)",fontsize=30)
ax2.set_ylabel("cos(x)",fontsize=30)
ax3.set_ylabel("tan(x)",fontsize=30)

ax1.plot(x,y1,c="r",linewidth=4)
ax2.plot(x,y2,c="r",linewidth=4)
ax3.plot(x,y3,c="r",linewidth=4)
plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
fig.suptitle("Our  first plot",fontsize=20)
ax1,ax2,ax3=axes
x=np.linspace(0,10,500)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

ax1.set_ylabel("sin(x)",fontsize=30)
ax2.set_ylabel("cos(x)",fontsize=30)
ax3.set_ylabel("tan(x)",fontsize=30)

ax1.plot(x,y1,c="r",linewidth=4)
ax2.plot(x,y2,c="r",linewidth=4)
ax3.plot(x,y3,c="r",linewidth=4)
plt.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
fig.suptitle("Our  first plot",fontsize=20)
ax1,ax2,ax3=axes
x=np.linspace(0,10,500)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

ax1.set_ylabel("sin(x)",fontsize=30)
ax2.set_ylabel("cos(x)",fontsize=30)
ax3.set_ylabel("tan(x)",fontsize=30)

ax1.plot(x,y1,c="r",linewidth=4)
ax2.plot(x,y2,c="r",linewidth=4)
ax3.plot(x,y3,c="r",linewidth=4)
plt.tight_layout()
plt.grid(axis="both")
plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
fig.suptitle("Our  first plot",fontsize=20)
ax1,ax2,ax3=axes
x=np.linspace(0,10,500)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

ax1.set_ylabel("sin(x)",fontsize=30)
ax2.set_ylabel("cos(x)",fontsize=30)
ax3.set_ylabel("tan(x)",fontsize=30)

ax1.plot(x,y1,c="r",linewidth=4)
ax2.plot(x,y2,c="r",linewidth=4)
ax3.plot(x,y3,c="r",linewidth=4)
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
item = ["Biscuit","chocolate","Candy","Cookies"]
Price = [10,20,15,35]
center = [5]

a,b,c = [plt.cm.Reds,plt.cm.Greens,plt.cm.Blues]
plt.pie(Price,labels=item,radius=1.5,autopct = "%1.2f%%",colors = [a(0.7),b(0.9),c(0.9),b(0.5)],shadow=True)
plt.pie(center,radius = 1.0,colors = "white")
plt.title("DonutChart")
plt.tight_layout()
plt.show()

# %%
item = ["Biscuit","chocolate","Candy","Cookies"]
Price = [10,20,15,35]
center = [5]

plt.pie(Price,labels=item,autopct = "%1.2f%%",startangle=90,explode=(0.1,0,0,0),shadow=True)
plt.title("Pie_chart")
plt.legend(item)
plt.show()

# %%
item = ["Biscuit","chocolate","Candy","Cookies"]
Price = [10,20,15,35]
center = [5]

a,b,c = [plt.cm.Reds,plt.cm.Greens,plt.cm.Blues]
plt.pie(Price,labels=item,radius=1.5,autopct = "%1.2f%%",colors = [a(0.7),b(0.9),c(0.9),b(0.5)],shadow=True)
plt.pie(center,radius = 1.0,colors = "white")
plt.title("DonutChart")
plt.tight_layout()
plt.legend(item)

plt.show()

# %%
item = ["Biscuit","chocolate","Candy","Cookies"]
Price = [10,20,15,35]
center = [5]

plt.pie(Price,labels=item,autopct = "%1.2f%%",startangle=90,explode=(0.5,0,0,0),shadow=True,wedgeprops={"width":0.2})
plt.title("Pie_chart")
plt.legend(item)
plt.show()

# %%
item = ["Biscuit","chocolate","Candy","Cookies"]
Price = [10,20,15,35]
center = [5]

plt.pie(Price,labels=item,autopct = "%1.2f%%",startangle=90,shadow=True,wedgeprops={"width":0.2}) #remove explode
plt.title("Pie_chart")
plt.legend(item)
plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
fig.suptitle("Our  first plot",fontsize=20)
ax1,ax2,ax3=axes
x=np.linspace(0,10,500)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

ax1.set_ylabel("sin(x)",fontsize=30)
ax2.set_ylabel("cos(x)",fontsize=30)
ax3.set_ylabel("tan(x)",fontsize=30)

ax1.plot(x,y1,c="r",linewidth=4)
ax2.plot(x,y2,c="r",linewidth=4)
ax3.plot(x,y3,c="r",linewidth=4)
plt.tight_layout()
plt.grid(axis="y")
plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
fig.suptitle("Our  first plot",fontsize=20)
ax1,ax2,ax3=axes
x=np.linspace(0,10,500)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

ax1.set_ylabel("sin(x)",fontsize=30)
ax2.set_ylabel("cos(x)",fontsize=30)
ax3.set_ylabel("tan(x)",fontsize=30)

ax1.plot(x,y1,c="r",linewidth=4)
plt.grid(axis="x")

ax2.plot(x,y2,c="r",linewidth=4)
plt.grid(axis="both")

ax3.plot(x,y3,c="r",linewidth=4)
plt.tight_layout()
plt.grid(axis="y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')


# make data
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')


# make data
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=1,
       wedgeprops={"linewidth":1, "edgecolor": "white",'width' : 0.3})
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
width = 0.3
data=[33,52,12,17,42,48]
labels=['Python','C','C++','PHP','Java','Ruby']

p_pie = ax.pie(data,radius=1,labels=labels, colors=colors,wedgeprops = {'width': width})

pets_data = [45, 41, 10, 4]
pets_labels = ['Apple', 'Carrot', 'Banana', 'Other']
pets_colors = ['orange', 'teal', 'powderblue', 'green']

pets_pie = ax.pie(pets_data, 
                  radius=1-width, 
                  labels=pets_labels,
                  labeldistance=0.7, 
                  colors=pets_colors, 
                  wedgeprops = {'width': width})

# %%
korea_scores=(554,536,538)
canada_scores=(518,523,525)
china_scores=(413,570,580)
franch_scores=(495,505,499)

index=np.arange(3)
bar_width=.1

plt.figure(figsize=(10, 6))
k1=plt.bar(index,korea_scores,bar_width,alpha=0.1,label="Korea")
c1=plt.bar(index+bar_width,canada_scores,bar_width,alpha=.9,label="Canada")
ch1=plt.bar(index+bar_width*2,china_scores,bar_width,alpha=.9,label="China")
f1=plt.bar(index+bar_width*3,franch_scores,bar_width,alpha=.9,label="Franch")

plt.xticks(index+.4/2,('Mathematics','Reading','Science'))
plt.xticks(rotation = 45)
plt.ylabel('Mean score in PISA in 2012',fontsize=14)
plt.xlabel('Subjects',fontsize=14)
plt.title('Test scores by Country',fontsize=20)
plt.grid(True)
plt.legend()
plt.show()

# %%
years = ['2016', '2017', '2018', '2019']
rice = [57, 50, 47, 30]
wheat = [43, 50, 53, 70]

plt.figure(figsize=(10, 6))

plt.bar(years, rice, label='Rice')
plt.bar(years, wheat, bottom=rice, label='Wheat')

plt.xlabel('Years', fontsize=14)
plt.ylabel('Preference (%)', fontsize=14)
plt.title('The results of Rice/Wheat export', fontsize=20)
plt.legend()
plt.show()

# %%
years = ['2016', '2017', '2018', '2019']
rice =  np.array([57, 50, 47, 30])
wheat =  np.array([43, 50, 53, 70])
mustard =  np.array([10, 16, 13, 15])

plt.figure(figsize=(10, 6))
 
plt.bar(years, rice, label='Rice')
plt.bar(years, wheat, bottom=rice, label='Wheat')
plt.bar(years, mustard, bottom=rice+wheat, label='Mustard seeds')

plt.xlabel('Years', fontsize=14)
plt.ylabel('Preference (%)', fontsize=14)
plt.title('The results of Rice,Wheat & Mustard seeds export', fontsize=20)
plt.legend()
plt.show()

# %%
films = ['Tanhaji', 'Baaghi 3', 'Love Aaj Kal', 'Jawaani Jaaneman', 'Street Dancer 3D']    
box_office = [367.65, 137.05, 44.77, 52.63, 97] 
plt.bar(films, box_office)        
plt.show()

# %%
#Grid lines

plt.bar(films, box_office)

# add grid lines
plt.grid(color='green', linestyle=':', linewidth=1.0, axis='x', alpha=0.5)

plt.ylabel('Box Office (crore . ₹)')  # labling y-axis
plt.xlabel('Film title')           # labling x-axis
plt.title('Box office of 5 different films of 2020 in the India')

plt.show()

# %%
plt.bar([1,3,5,7,9],[5,2,7,8,2], label="Example one")
plt.bar([2,4,6,8,10],[8,6,2,5,6], label="Example two", color='g')
plt.legend()
plt.xlabel('bar number')
plt.ylabel('bar height')

plt.title('Epic Graph\nAnother Line! Whoa')

plt.show()

# %%
# plotting the chart horizontally
plt.barh(films, box_office)

plt.xlabel('Box Office (crore . ₹)')
plt.ylabel('Film title')
plt.title('Box office of 5 different films of 2020 in the India')

plt.show()

# %%
years=[1950,1955,1960,1965,1970,1980,1985,1990,1995,2000,2005,2010,2015]
pops=[2.5,2.7,3.0,3.3,3.6,4.0,4.4,4.8,5.3,5.7,6.1,6.5,7.3]

plt.plot(years,pops,color=(255/255,100/255,100/255))  #RGB tuple
plt.ylabel("Population in Billions")
plt.xlabel("Population growth by year")
plt.title("Population Growth")
# Out:
# Text(0.5, 1.0, 'Population Growth')

# %%
fig, ax = plt.subplots()
x = np.linspace(0,10,300)
y = np.sin(x)+x

ax.plot(x,y)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,5))
fig.suptitle("Our first plot", fontsize = 40)
ax.plot(x,y,c = 'r', linestyle = 'dashed', linewidth = 4)

# %%
fig, ax = plt.subplots(figsize = (10,5))
fig.suptitle("Our first plot", fontsize = 40)
ax.plot(x,y,c = 'r', linestyle = 'dashed', linewidth = 4)
ax.set_ylabel("function", fontsize = 20)
ax.set_xlabel("argument", fontsize = 20)

#ax.set_xlim(1, 20)  # this code is to change scale of your data
#ax.set_ylim(1, 20)

plt.tick_params(axis='both',labelsize=50)

# for xtick in ax.xaxis.get_major_ticks():
#     xtick.label.set_fontsize(50)

# for ytick in ax.yaxis.get_major_ticks():
#     ytick.label.set_fontsize(10)

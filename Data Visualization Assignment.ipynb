# %% [markdown]
# #  Answer according to the Intellipaat

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [raw]
# Description of the Dataset:
# This dataset contains these columns: id, date, price, bedrooms, bathrooms,
# sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above,
# sqft_basement, yr_built, yr_renovated, zip code, lat, long, sqft_living15, sqft_lot15.
#
# dataset---> home_data

# %% [raw]
# Data Visualization
# 1. Which of the following libraries should be imported for creating charts in python?
# a. Pandas
# b. Random
# c. Math
# d. Matplotlib

# %%
#Answer--->Matplotlib

# %% [raw]
# 2. How to visualize the correlation pattern in the dataset?
# a. Histogram
# b. Bar plot
# c. Scatterplot
# d. Heatmap

# %%
#Answer--->Heatmap

# %% [raw]
# 3. Which function can we use for plotting the boxplot?
# a. sns.box()
# b. plt.bplot()
# c. sns.boxplot()
# d. pl.boxplt()

# %%
#Answer----> sns.boxplot()

# %% [raw]
# 4. What insights can we extract from the boxplot?
# a. 2nd quartile
# b. 1st quadrille
# c. 3rd quartile
# d. All of the above

# %%
#Answer--->d    All of the above

# %% [raw]
# 5. Which visualization is not part of matplotlib?
# a. Table plot
# b. Area plot
# c. Violin plot
# d. None of the above

# %%
#Answer---> None of the above

# %% [raw]
# 6. From which visualization we can find the median/mean value of the data?
#
# a. Bar plot
# b. Boxplot
# c. Violin plot
# d. All of the above

# %%
#Answer---> All of the Aboove

# %% [raw]
# 7. Which of the following is correct?
# a. plt.scatter(data[‘gender’],data[‘age’])
# b. plt.boxpt(data[‘gender’],data[‘age’])
# c. plt.scatter(data[‘salary’],data[‘age’])
# d. None of the above

# %%
#Answer--->None of the above

# %% [raw]
# 8. What error you will get after executing the below
# code:
# data.box('bedrooms','grade')
# a. Attribute error
# b. Syntax error
# c. Runtime error
# d. None of the above

# %%
data=pd.read_csv("home_data.csv")

# %%
data.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
data.box('bedrooms','grade')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 data.box('bedrooms','grade')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'box'

# %%
#Answer ----> Attribute error

# %% [raw]
# 9. Which of the following code you can use for plotting thepie chart:
# a. plt.pie(x)
# b. sns.pie(x)
# c. Both of the above
# d. None of the above

# %%
#answer---> a. plt.pie(x)

# %%
data["bedrooms"].value_counts().keys()
# Out:
# Int64Index([3, 4, 2, 5, 6, 1, 7, 0, 8, 9, 10, 11, 33], dtype='int64')

# %%
plt.pie(data["bedrooms"].value_counts(),labels=data["bedrooms"].value_counts().keys(),autopct="0.2g")
# Out:
# ([<matplotlib.patches.Wedge at 0x179500d05e0>,
#   <matplotlib.patches.Wedge at 0x179500d0a00>,
#   <matplotlib.patches.Wedge at 0x17950772160>,
#   <matplotlib.patches.Wedge at 0x17950772880>,
#   <matplotlib.patches.Wedge at 0x17950772fa0>,
#   <matplotlib.patches.Wedge at 0x17950779700>,
#   <matplotlib.patches.Wedge at 0x17950779e20>,
#   <matplotlib.patches.Wedge at 0x17950780580>,
#   <matplotlib.patches.Wedge at 0x17950780ca0>,
#   <matplotlib.patches.Wedge at 0x17950787400>,
#   <matplotlib.patches.Wedge at 0x179500d05b0>,
#   <matplotlib.patches.Wedge at 0x17950791250>,
#   <matplotlib.patches.Wedge at 0x17950791970>],
#  [Text(0.15656075139311776, 1.088801511352378, '3'),
#   Text(-0.830805624944281, -0.7209452223025983, '4'),
#   Text(0.5706836696875345, -0.9403829800416261, '2'),
#   Text(1.016794379074737, -0.41967748412563244, '5'),
#   Text(1.0921954697280511, -0.13080158984324933, '6'),
#   Text(1.0985848831562623, -0.055778620461083096, '1'),
#   Text(1.0998542308076895, -0.017907288304646992, '7'),
#   Text(1.0999567583805037, -0.009753445188981372, '0'),
#   Text(1.0999857639411308, -0.0055963494214564535, '8'),
#   Text(1.0999970247678785, -0.0025584178344051703, '9'),
#   Text(1.09999943043958, -0.001119389387012179, '10'),
#   Text(1.0999998953510688, -0.0004798204226596121, '11'),
#   Text(1.0999999883584197, -0.0001600358598576947, '33')],
#  [Text(0.08539677348715513, 0.5938917334649334, '0.2g'),
#   Text(-0.4531667045150623, -0.3932428485286899, '0.2g'),
#   Text(0.31128200164774605, -0.512936170931796, '0.2g'),
#   Text(0.5546151158589473, -0.22891499134125404, '0.2g'),
#   Text(0.5957429834880279, -0.07134632173268143, '0.2g'),
#   Text(0.599228118085234, -0.030424702069681682, '0.2g'),
#   Text(0.5999204895314669, -0.009767611802534722, '0.2g'),
#   Text(0.5999764136620929, -0.005320061012171656, '0.2g'),
#   Text(0.5999922348769804, -0.003052554229885338, '0.2g'),
#   Text(0.5999983771461155, -0.0013955006369482745, '0.2g'),
#   Text(0.5999996893306799, -0.0006105760292793702, '0.2g'),
#   Text(0.5999999429187647, -0.0002617202305416066, '0.2g'),
#   Text(0.5999999936500471, -8.729228719510619e-05, '0.2g')])

# %% [raw]
# 10. What is the correct way of plotting violin plot?
# a. sns.violinplot(data=data, y = 'price',x= 'waterfront')
# b. sns.violin(data=data, y = 'price',x = 'waterfront')
# c. plt.violinplot(data=data, y = 'price',x='waterfront')
# d. All of the above

# %%
#Answer---->a    sns.violinplot(data=data,y="price",x="waterfront")

# %% [raw]
# 11. Select the incorrect syntax:
# a. plt.figsize()
# b. plt.figtext()
# c. plt.figpic()
# d. Both A and C

# %%
#Answer----> Both A  and C

# %% [raw]
# 12. What inference you can extract from the below graph:
# a. The cheapest house is having 3 floors.
# b. The costliest house is having 2.5 floors.
# c. The maximum number of houses are having 1 floor only
# d. All of the above

# %%
plt.xlabel("No of Floors")
plt.grid()
sns.scatterplot(data=data,y="price",x="floors")
# Out:
# <AxesSubplot:xlabel='No of Floors', ylabel='price'>

# %%
#Answer -- b. The costliest house is having 2.5 floors.

# %%
data.sort_values(by="price")
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000    75000         1       0.00          670
# 15293    40000362  20140506T000000    78000         2       1.00          780
# 465    8658300340  20140523T000000    80000         1       0.75          430
# 16198  3028200080  20150324T000000    81000         2       1.00          730
# 8274   3883800011  20141105T000000    82000         3       1.00          860
# ...           ...              ...      ...       ...        ...          ...
# 1448   8907500070  20150413T000000  5350000         5       5.00         8000
# 4411   2470100110  20140804T000000  5570000         5       5.75         9200
# 9254   9208900037  20140919T000000  6885000         6       7.75         9890
# 3914   9808700762  20140611T000000  7062500         5       4.50        10040
# 7252   6762700020  20141013T000000  7700000         6       8.00        12050
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149      43377     1.0           0     0  ...      3         670
# 15293     16344     1.0           0     0  ...      5         780
# 465        5050     1.0           0     0  ...      4         430
# 16198      9975     1.0           0     0  ...      5         730
# 8274      10426     1.0           0     0  ...      6         860
# ...         ...     ...         ...   ...  ...    ...         ...
# 1448      23985     2.0           0     4  ...     12        6720
# 4411      35069     2.0           0     0  ...     13        6200
# 9254      31374     2.0           0     4  ...     13        8860
# 3914      37325     2.0           1     2  ...     11        7680
# 7252      27600     2.5           0     3  ...     13        8570
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1149               0      1966             0    98022  47.2638 -121.906
# 15293              0      1942             0    98168  47.4739 -122.280
# 465                0      1912             0    98014  47.6499 -121.909
# 16198              0      1943             0    98168  47.4808 -122.315
# 8274               0      1954             0    98146  47.4987 -122.341
# ...              ...       ...           ...      ...      ...      ...
# 1448            1280      2009             0    98004  47.6232 -122.220
# 4411            3000      2001             0    98039  47.6289 -122.233
# 9254            1030      2001             0    98039  47.6305 -122.240
# 3914            2360      1940          2001    98004  47.6500 -122.214
# 7252            3480      1910          1987    98102  47.6298 -122.323
#
#        sqft_living15  sqft_lot15
# 1149            1160       42882
# 15293           1700       10387
# 465             1200        7500
# 16198            860        9000
# 8274            1140       11250
# ...              ...         ...
# 1448            4600       21750
# 4411            3560       24345
# 9254            4540       42730
# 3914            3930       25449
# 7252            3940        8800
#
# [21613 rows x 21 columns]

# %%
data.sort_values(by="price",ascending=False)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 7252   6762700020  20141013T000000  7700000         6       8.00        12050
# 3914   9808700762  20140611T000000  7062500         5       4.50        10040
# 9254   9208900037  20140919T000000  6885000         6       7.75         9890
# 4411   2470100110  20140804T000000  5570000         5       5.75         9200
# 1448   8907500070  20150413T000000  5350000         5       5.00         8000
# ...           ...              ...      ...       ...        ...          ...
# 8274   3883800011  20141105T000000    82000         3       1.00          860
# 16198  3028200080  20150324T000000    81000         2       1.00          730
# 465    8658300340  20140523T000000    80000         1       0.75          430
# 15293    40000362  20140506T000000    78000         2       1.00          780
# 1149   3421079032  20150217T000000    75000         1       0.00          670
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252      27600     2.5           0     3  ...     13        8570
# 3914      37325     2.0           1     2  ...     11        7680
# 9254      31374     2.0           0     4  ...     13        8860
# 4411      35069     2.0           0     0  ...     13        6200
# 1448      23985     2.0           0     4  ...     12        6720
# ...         ...     ...         ...   ...  ...    ...         ...
# 8274      10426     1.0           0     0  ...      6         860
# 16198      9975     1.0           0     0  ...      5         730
# 465        5050     1.0           0     0  ...      4         430
# 15293     16344     1.0           0     0  ...      5         780
# 1149      43377     1.0           0     0  ...      3         670
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252            3480      1910          1987    98102  47.6298 -122.323
# 3914            2360      1940          2001    98004  47.6500 -122.214
# 9254            1030      2001             0    98039  47.6305 -122.240
# 4411            3000      2001             0    98039  47.6289 -122.233
# 1448            1280      2009             0    98004  47.6232 -122.220
# ...              ...       ...           ...      ...      ...      ...
# 8274               0      1954             0    98146  47.4987 -122.341
# 16198              0      1943             0    98168  47.4808 -122.315
# 465                0      1912             0    98014  47.6499 -121.909
# 15293              0      1942             0    98168  47.4739 -122.280
# 1149               0      1966             0    98022  47.2638 -121.906
#
#        sqft_living15  sqft_lot15
# 7252            3940        8800
# 3914            3930       25449
# 9254            4540       42730
# 4411            3560       24345
# 1448            4600       21750
# ...              ...         ...
# 8274            1140       11250
# 16198            860        9000
# 465             1200        7500
# 15293           1700       10387
# 1149            1160       42882
#
# [21613 rows x 21 columns]

# %%
data.floors.value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
#13. Which of the following statements are correct with respect to the below image:
plt.xlabel("No of Grades")
# %matplotlib inline
plt.grid()
plt.hist(x=data["grade"])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1.0000e+00, 3.0000e+00, 2.9000e+01, 2.4200e+02, 2.0380e+03,
#         1.5049e+04, 2.6150e+03, 1.1340e+03, 3.9900e+02, 1.0300e+02]),
#  array([ 1. ,  2.2,  3.4,  4.6,  5.8,  7. ,  8.2,  9.4, 10.6, 11.8, 13. ]),
#  <BarContainer object of 10 artists>)

# %% [raw]
# a. The maximum number of houses have grades of either 7 or 8.
# b. Around 2000 houses are having grades between 6 and 7.
# c. Both of the above.
# d. None of the above.

# %%
#ANSWER-->c. Both of the above.

# %%
#14. Which of the following statements is/are correct with respect to the below image:
sns.scatterplot(data=data,y="grade",x="price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='grade'>

# %% [raw]
# a. The average-priced house has grades between 10 and 12.
# b. The costliest house is having a grade below 10.
# c. As the price is getting higher, grades are also getting higher.
# d. The average-priced house is having average grades.

# %%
#Answer--->c. As the price is getting higher, grades are also getting higher.

# %%
#15. Which statement is correct with respect to the below image:
plt.xlabel("No of Views")
plt.ylabel("Counts")
#plt.hist(data["view"])
sns.histplot(data=data,x="view",discrete =True)
# Out:
# <AxesSubplot:xlabel='No of Views', ylabel='Counts'>

# %%
plt.grid()
plt.hist(data["view"])
plt.show()

# %% [raw]
# a. The maximum number of houses are not having any view.
# b. Around 300 houses are having only one view.
# c. The 4th category is having the least count of houses.
# d. All of the above.

# %%
#Answer----> a. The maximum number of houses are not having any view.

# %%
#16. Which of the following statements are correct with respect to the below image:
plt.figure(figsize=(15,6))
sns.boxplot(data=data,x="floors",y="bedrooms")
# Out:
# <AxesSubplot:xlabel='floors', ylabel='bedrooms'>

# %% [raw]
# a. All categories of floors are having outliers.
# b. We can handle the outliers by replacing them with the mean of the column.
# c. We can handle the outliers by replacing them with the mode of the column.
#
# a. Only a is correct
# b. a&c are correct
# c. b&c are correct
# d. All statements are correct

# %%
#Answer---->d. All statements are correct

# %%
#17. Which statement is correct with respect to the below image
#sns.histplot(data=data,x="zipcode")
plt.figure(figsize=(16,6))
plt.grid()
plt.xticks(rotation=45)
plt.hist(data["zipcode"])
# Out:
# (array([2857., 4384., 3345., 1699.,  351., 4259., 1811., 1134., 1040.,
#          733.]),
#  array([98001. , 98020.8, 98040.6, 98060.4, 98080.2, 98100. , 98119.8,
#         98139.6, 98159.4, 98179.2, 98199. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data=data,x="zipcode",kde=True)
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='Count'>

# %% [raw]
# a. Maximum houses have zip codes between 98100 and 98125.
# b. A Smaller number of houses have zip codes between 98075 and 98100.
# c. The houses that are having zip codes between 98000 and 98050 are having the costliest houses.
# d. All of the above.

# %%
#Answer--->b. A Smaller number of houses have zip codes between 98075 and 98100.

# %%
#18. Which of the following statements is/are correct with respect to the below image:
sns.scatterplot(data=data,x="sqft_living",y="price")
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %% [raw]
# a. If the price is getting higher, the area of sqft_living is also increasing.
# b. If the price is getting lower, the area of sqft_living is decreasing.
# c. The costliest house has the maximum sqft of living area.
#
# A. A and B
# B. A and C
# C. B and C
# D. Only A
# E. Only B
# F. Only C

# %%
#ANswer--->A.   A and B

# %%
#19. Which of the following statements are correct with respect to the below image:
sns.violinplot(data=data,x="view",y="price")
# Out:
# <AxesSubplot:xlabel='view', ylabel='price'>

# %% [raw]
# a. The interquartile range for the 4th category of view is the highest among the rest of the views.
# b. The houses that are having no view, are having a high probability of having a cheap house.
# c. Both of the above.
# d. None of the above.

# %%
#Answer--->c. Both of the above.

# %%
#20. Which of the following statements is/are correct with respect to the below image:

sns.boxplot(data=data,y="sqft_living",x="floors")
# Out:
# <AxesSubplot:xlabel='floors', ylabel='sqft_living'>

# %% [raw]
# a. The average area of square foot living in 3 number floors is very close to its 1st quartile value.
# b. The 1st quartile value and the minimum square feet of living space are almost the same.
# c. Each category of floors are having outliers.
# d. All of the above.(options A and C)

# %%
#Answer--->d. All of the above. (ACtual answer A and C)

# %%
#21. Which of the following statements is/are correct with respect to the below image:
sns.scatterplot(data=data,x="condition",y="price")
# Out:
# <AxesSubplot:xlabel='condition', ylabel='price'>

# %% [raw]
# a. If the condition is increasing, the price of the house is also increasing.
# b. The costliest house is having the 5th category of condition.
# c. The 4th category of the condition is having the maximum number of houses.
# d. None of the above.

# %%
#Answer--->d  None of the above

# %%
data["condition"].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
import pandas as pd 
data = pd.read_csv("Boston1.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.shape
# Out:
# (506, 14)

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data_ = data.loc[:,['lstat','medv']]
data_.head(5)
# Out:
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
import matplotlib.pyplot as plt
data.plot(x='lstat',y='medv',style='o')
plt.xlabel('lstat')
plt.ylabel('medv')
plt.show()

# %%
X = pd.DataFrame(data['lstat'])
y = pd.DataFrame(data['medv'])

# %%
X
# Out:
#      lstat
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# ..     ...
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 1 columns]

# %%
y
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
X.size, y.size
# Out:
# (506, 506)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 1)
# (102, 1)
# (404, 1)
# (102, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor
# Out:
# LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [34.33497839]

# %%
print(regressor.coef_)
# Out:
# [[-0.92441715]]

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([[27.37411725],
#        [27.69766325],
#        [16.95593597],
#        [26.84719947],
#        [24.91516763],
#        [24.05545968],
#        [29.99021779],
#        [22.28057875],
#        [17.76942306],
#        [26.1908633 ],
#        [27.17998965],
#        [30.07341533],
#        [21.75366098],
#        [24.86894677],
#        [23.50080939],
#        [23.12179836],
#        [12.85152382],
#        [30.05492699],
#        [27.46655897],
#        [ 7.03693995],
#        [23.70418116],
#        [18.94343284],
#        [25.75638724],
#        [28.67754543],
#        [30.0179503 ],
#        [11.7884441 ],
#        [15.53233356],
#        [24.6008658 ],
#        [27.62370988],
#        [15.06088081],
#        [29.25992824],
#        [17.2702378 ],
#        [31.672657  ],
#        [19.13756044],
#        [25.9320265 ],
#        [21.77214932],
#        [17.88959729],
#        [29.40783498],
#        [12.75908211],
#        [20.48720948],
#        [27.54975651],
# ...

# %%
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred
# Out:
#      Predicted
# 0    27.374117
# 1    27.697663
# 2    16.955936
# 3    26.847199
# 4    24.915168
# ..         ...
# 97   26.791734
# 98   30.507891
# 99   22.317555
# 100  19.830873
# 101  16.909715
#
# [102 rows x 1 columns]

# %%
y_pred
# Out:
#      Predicted
# 0    27.374117
# 1    27.697663
# 2    16.955936
# 3    26.847199
# 4    24.915168
# ..         ...
# 97   26.791734
# 98   30.507891
# 99   22.317555
# 100  19.830873
# 101  16.909715
#
# [102 rows x 1 columns]

# %%
y_test
# Out:
#      medv
# 307  28.2
# 343  23.9
# 47   16.6
# 67   22.0
# 362  20.8
# ..    ...
# 92   22.9
# 224  44.8
# 110  21.7
# 426  10.2
# 443  15.4
#
# [102 rows x 1 columns]

# %%
from sklearn import metrics 
import numpy as np
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 5.078127727696938
# Mean Squared Error: 46.99482091954711
# Root Mean Squared Error: 6.855276866731723

# %%
xyz = regressor.predict([[5.12]])
xyz
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[29.60196258]])

# %% [markdown]
# # Mulitple Linear Regression

# %%
#creating model using top 2 correlated values

# %%
data_ = data.loc[:,['lstat','medv',"rm"]]
data_.head(5)
# Out:
#    lstat  medv     rm
# 0   4.98  24.0  6.575
# 1   9.14  21.6  6.421
# 2   4.03  34.7  7.185
# 3   2.94  33.4  6.998
# 4   5.33  36.2  7.147

# %%
data_[['lstat',"rm"]]
# Out:
#      lstat     rm
# 0     4.98  6.575
# 1     9.14  6.421
# 2     4.03  7.185
# 3     2.94  6.998
# 4     5.33  7.147
# ..     ...    ...
# 501   9.67  6.593
# 502   9.08  6.120
# 503   5.64  6.976
# 504   6.48  6.794
# 505   7.88  6.030
#
# [506 rows x 2 columns]

# %%
data_["medv"]
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %% [raw]
#                                         import matplotlib.pyplot as plt
#                                         data.plot(x=data_[['lstat',"rm"]],y=data_['medv'],style=['o','^'])
#                                         plt.xlabel('lstat and rm')
#                                         plt.ylabel('medv')
#                                         plt.show()

# %%
# we would not be able to show the data as there are two columns in it thats why not able to plot

# %%
X = pd.DataFrame(data[['lstat','rm']])
y = pd.DataFrame(data['medv'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)        #test_size=0.2 means 20% random_state =1 works as seed

# %%
print("X_train=",X_train, "X_test=",X_test, "y_train=",y_train, "y_test=",y_test)
# Out:
# X_train=      lstat     rm
# 42    5.81  6.169
# 58    6.86  6.145
# 385  30.81  5.277
# 78   12.34  6.232
# 424  17.16  5.565
# ..     ...    ...
# 255   9.25  5.876
# 72    5.52  6.065
# 396  19.37  6.405
# 235  10.88  6.086
# 37    8.77  5.850
#
# [404 rows x 2 columns] X_test=      lstat     rm
# 307   7.53  6.849
# 343   7.18  6.696
# 47   18.80  6.030
# 67    8.10  5.878
# 362  10.19  5.362
# ..     ...    ...
# 92    8.16  6.442
# 224   4.14  8.266
# 110  13.00  6.195
# 426  15.69  5.837
# 443  18.85  6.485
#
# [102 rows x 2 columns] y_train=      medv
# 42   25.3
# 58   23.3
# 385   7.2
# 78   21.2
# 424  11.7
# ..    ...
# 255  20.9
# 72   22.8
# 396  12.5
# 235  24.0
# 37   21.0
#
# [404 rows x 1 columns] y_test=      medv
# 307  28.2
# 343  23.9
# 47   16.6
# 67   22.0
# 362  20.8
# ..    ...
# 92   22.9
# 224  44.8
# 110  21.7
# 426  10.2
# 443  15.4
#
# [102 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor
# Out:
# LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [2.49341453]

# %%
print(regressor.coef_)
# Out:
# [[-0.65930795  4.5389694 ]]

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([[28.61622711],
#        [28.15252257],
#        [17.46841058],
#        [23.83308229],
#        [20.11302046],
#        [24.08422317],
#        [29.48803431],
#        [21.45666108],
#        [17.69002299],
#        [25.81147815],
#        [28.02841447],
#        [30.65488056],
#        [19.53306699],
#        [22.00911706],
#        [22.10453808],
#        [19.95054951],
#        [17.35070535],
#        [39.04332676],
#        [25.56388593],
#        [ 5.38301406],
#        [20.80619355],
#        [17.06125697],
#        [26.18244883],
#        [27.5759386 ],
#        [27.96456395],
#        [13.17465724],
#        [16.75264832],
#        [22.84826381],
#        [31.83988873],
#        [13.21188887],
#        [28.73569359],
#        [15.76351329],
#        [37.06068782],
#        [20.02748958],
#        [24.38773328],
#        [20.43135218],
#        [19.54593109],
#        [31.41931748],
#        [ 5.88742238],
#        [20.36824038],
#        [26.39938741],
# ...

# %%
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred
# Out:
#      Predicted
# 0    28.616227
# 1    28.152523
# 2    17.468411
# 3    23.833082
# 4    20.113020
# ..         ...
# 97   26.353503
# 98   37.283001
# 99   22.041327
# 100  18.642837
# 101  19.500676
#
# [102 rows x 1 columns]

# %%
from sklearn import metrics 
import numpy as np
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.505211813354641
# Mean Squared Error: 32.08375607139392
# Root Mean Squared Error: 5.664252472426871

# %% [markdown]
# # multiple regression

# %%
import pandas as pd 
dataset = pd.read_csv("Boston1.csv")
dataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X = pd.DataFrame(dataset.iloc[:,:-1])
y = pd.DataFrame(dataset.iloc[:,-1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404, 1)
# (102, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
v = pd.DataFrame(regressor.coef_,index=['Co-efficient']).transpose()
v
# Out:
#     Co-efficient
# 0      -0.130800
# 1       0.049403
# 2       0.001095
# 3       2.705366
# 4     -15.957050
# 5       3.413973
# 6       0.001119
# 7      -1.493081
# 8       0.364422
# 9      -0.013172
# 10     -0.952370
# 11      0.011749
# 12     -0.594076

# %%
w = pd.DataFrame(X.columns, columns=['Attribute'])

# %%
w
# Out:
#    Attribute
# 0       crim
# 1         zn
# 2      indus
# 3       chas
# 4        nox
# 5         rm
# 6        age
# 7        dis
# 8        rad
# 9        tax
# 10   ptratio
# 11     black
# 12     lstat

# %%
X.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat'],
#       dtype='object')

# %%
coeff_df = pd.concat([w,v], axis=1, join='inner')
coeff_df
# Out:
#    Attribute  Co-efficient
# 0       crim     -0.130800
# 1         zn      0.049403
# 2      indus      0.001095
# 3       chas      2.705366
# 4        nox    -15.957050
# 5         rm      3.413973
# 6        age      0.001119
# 7        dis     -1.493081
# 8        rad      0.364422
# 9        tax     -0.013172
# 10   ptratio     -0.952370
# 11     black      0.011749
# 12     lstat     -0.594076

# %%
y_pred = regressor.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred
# Out:
#      Predicted
# 0    37.563118
# 1    32.144451
# 2    27.065736
# 3     5.670806
# 4    35.099826
# ..         ...
# 97   21.912956
# 98   22.394774
# 99   13.193354
# 100  23.969911
# 101  21.199147
#
# [102 rows x 1 columns]

# %%
y_test
# Out:
#      medv
# 226  37.6
# 292  27.9
# 90   22.6
# 373  13.8
# 273  35.2
# ..    ...
# 349  26.6
# 212  22.4
# 156  13.1
# 480  23.0
# 248  24.5
#
# [102 rows x 1 columns]

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 3.2132704958423632
# Mean Squared Error: 20.869292183770522
# Root Mean Squared Error: 4.568292042303176
